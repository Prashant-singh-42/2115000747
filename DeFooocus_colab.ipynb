# %%
#@title DeFooocus
#@markdown **Launch the interface DeFocus (Fooocus fork)** | You need to connect with T4/A100/V100
#@markdown ****
#@markdown *Attention!* When working in the interface with the FaceSwap and CPDS controlnet, crashes are possible; it is also recommended to work in *Extreme speed* mode for additional stability. When working with the ImagePrompt and PyraCanny controls, 85% of the work will be stable.
#@markdown ****

print("[DeFooocus] Preparing ...")

theme = "dark" #@param ["dark", "light"]
preset = "deafult" #@param ["deafult", "realistic", "anime", "lcm", "sai", "turbo", "lighting", "hypersd", "playground_v2.5", "dpo", "spo", "sd1.5"]
advenced_args = "--share --attention-split --always-high-vram --disable-offload-from-vram --all-in-fp16" #@param {type: "string"}

if preset != "deafult":
  args = f"{advenced_args} --theme {theme} --preset {preset}"
else:
  args = f"{advenced_args} --theme {theme}"

# !pip install -q pygit2==1.12.2
# %cd /content
# !git clone https://github.com/ehristoforu/DeFooocus.git
# %cd /content/DeFooocus
# !pip install -q -r requirements_versions.txt

print("[DeFooocus] Starting ...")
# !python entry_with_update.py $args
# Out:
# [DeFooocus] Preparing ...
# [DeFooocus] Starting ...
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--attention-split', '--always-high-vram', '--disable-offload-from-vram', '--all-in-fp16', '--theme', 'dark']
# Python 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# Fooocus version: 0.2
# Total VRAM 15095 MB, total RAM 12978 MB
# Forcing FP16.
# Set vram state to: HIGH_VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using split optimization for cross attention
# 2025-08-09 11:39:49.823960: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# =========================
# STEP 3 — Download Your Model from CivitAI using Cookie Auth
# =========================

# 1️⃣ Paste your cookie string from browser dev tools:
#    Open CivitAI in Chrome → F12 → Network → click any request → Headers → "cookie"
cookie_header = "__Host-next-auth.csrf-token=14fb3db3bbea8177632e468aa5a0f0550f62989c3ce06e160da784406240ec85%7Cc4347018ce78acc74d07d399d14e26624f14c9352fe99e92bb4bead79f75b7d8; ref_login_redirect_reason=download-auth; ref_landing_page=%2Flogin%3FreturnUrl%3D%252Fmodel-versions%252F2017049%26reason%3Ddownload-auth; _ga=GA1.1.1376344240.1754738178; __Secure-next-auth.callback-url=https%3A%2F%2Fcivitai.com%2Fmodel-versions%2F2017049; _ga_N6W8XF7DXE=GS2.1.s1754738178$o1$g1$t1754739036$j60$l0$h0; __Secure-civitai-token=eyJhbGciOiJkaXIiLCJlbmMiOiJBMjU2R0NNIn0..v0yKONJMsrl0BMeT.FrJ9wILtv5A7VOGw2mRdYNgcBdZFnh1pTI0WO3edPmCODs19BNAadAboIXRADpYtxoYLTTiQBAOGo31S-e_L2jmfKn2uf4iHWQtm1P4UhdYY6L7i8ANlpN3VvcMwEt8ZjbwI1cwEcx1z6AvbyRh0jtl1eXIj4FeMwC9gw-topFQ0NtIqzfVCrXFXwdK5PF7XSlT0RdP46UnLi7IfmJr5OMQN7xg0AW3Kdax4cr113tpTrwdL37pHnJEc0f_8Bkrqxe8JJSI6ebywTZAFJvjxQH9fiNA3WLn10Nl3KguoilVrepGHal7saopcu3y9mN4yqiPm0Z0_PQMq8suh4gC5rw0IFZDDw7C0Yx7NM1ggSzd1-WkP7d1VX1Xfhk8IScXzTfWChMy3Th188TTmYMwX3wL7MUwdrisjryB8E70FAr9rMxITxCW6XvQaU9aByeA9YEJJpoZCW7tm6YLtGZZy1Wft5vtAI3VLgJDlnx6OPgfmq54Wxvpj7ir04u1BXWVAnaMCKejhec2ABueNh2Hqw4uDFwg0dxvhUUxZQsruXf2JdMp1WQ239eMgxmfHd58ccJO62Du2oza6yf0_sUcVvlwIHZGGk7CJEwedFfBmgg608J9fX3HI3eIL32b6mYzwWAfh5dMotR1DIVwC7x9bavgu45tS7pA-XaYeCv0zuqvvTb6i-J868LYJfTXO4b8RHK9ShUBlimiZxcZThPSPAP00wLuwG4Ji-EoCR714lxZgm3HjPYob_hxVHMM8N7tpLDe2sT5nZZpcZq5FEBtGZLHB1uRqmsIY3DvbgZthje2At43VdecQWZvwkpEUKVD_npLvYomciRu6ArzwTlyUCq1T0jqWyaSn7BIxHOELGErSTr3_VuxR3Ny-hvM9z9sKdsC7nLLOU6WUAFEJOlKA15O795doT2UOBz6-OxNIuqHb1hjv0tBvAz2KEwQPsptnsUUy6KlQv3EAoqgqCXjajSuz5SMhDEJd4eRwv_n9uKfmMVFynzcbqJ_-0fiT335E28a12yGOkddhXFozHEUj1pj9hF6nyLMzFdSdeGtNlavza2oTr6pw8helhmoZqVDqK_RcMqveGKzuFGUn3yWk0qQG_ARIJ3K6ZgR_P91jZG_Il0RGoGRctFJgHW7WHgAtUOn3i6Pplxizm5cnjKPpkw8x4dmkNV8tmpwcUP08_q4KNx3NpZFIsHgWpyU_UCc-YTbUbzx_SWJ2j5V8HXfYw3D-izB3CDK2ml7pMYwjyOA7J-6Dsapl1A.aNXBc0DpHI9gLqMPEPeuvw"

# 2️⃣ Model download URL
model_url = "https://civitai.com/api/download/models/2017049?type=Model&format=SafeTensor&size=pruned&fp=fp16"
model_filename = "civitai_model.safetensors"

# !mkdir -p /content/DeFooocus/models/Stable-diffusion
# !wget --header="cookie: {cookie_header}" -O /content/DeFooocus/models/Stable-diffusion/$model_filename "$model_url"
# Out:
# --2025-08-09 11:37:20--  https://civitai.com/api/download/models/2017049?type=Model&format=SafeTensor&size=pruned&fp=fp16
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::ac42:98ba, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/5082433/ilustmixV80.OpLR.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22ilustmix_v80.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250809/us-east-1/s3/aws4_request&X-Amz-Date=20250809T113720Z&X-Amz-SignedHeaders=host&X-Amz-Signature=ee7dda84e73814171c1b0cfa74f9a2fc64b6778cff8ebcce72f4bb98bc5be8cd [following]
# ...

# %%
print("[DeFooocus] Preparing ...")

theme = "dark" #@param ["dark", "light"]
preset = "lust" #@param ["deafult", "realistic", "anime", "lcm", "sai", "turbo", "lighting", "hypersd", "playground_v2.5", "dpo", "spo", "sd1.5", "lust"]
advenced_args = "--share --attention-split --always-high-vram --disable-offload-from-vram --all-in-fp16" #@param {type: "string"}

if preset != "deafult":
  args = f"{advenced_args} --theme {theme} --preset {preset}"
else:
  args = f"{advenced_args} --theme {theme}"

# !pip install -q pygit2==1.12.2
# %cd /content
# !git clone https://github.com/ehristoforu/DeFooocus.git
# %cd /content/DeFooocus
# !pip install -q -r requirements_versions.txt

print("[DeFooocus] Starting ...")
# !python entry_with_update.py $args
# Out:
# [DeFooocus] Preparing ...
# [DeFooocus] Starting ...
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--attention-split', '--always-high-vram', '--disable-offload-from-vram', '--all-in-fp16', '--theme', 'dark', '--preset', 'lust']
# Python 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# Fooocus version: 0.2
# Loaded preset: /content/DeFooocus/presets/lust.json
# Total VRAM 15095 MB, total RAM 12978 MB
# Forcing FP16.
# Set vram state to: HIGH_VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using split optimization for cross attention
# 2025-08-09 12:04:54.116879: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
